# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math
import pandas as pd 
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error


data=pd.read_csv('Spring 2023 data.csv')
data.fillna(1.5,inplace=True)
data['5:00 AM'].replace(1.5,data['5:00 AM'].mean(), inplace=True)
data['6:00 AM'].replace(1.5,data['6:00 AM'].mean(), inplace=True)
type(data['7:00 AM'][5])
data['7:00 AM'] = pd.to_numeric(data['7:00 AM'], errors='coerce', downcast='integer')
data['7:00 AM'].replace(1.5,data['7:00 AM'].mean(), inplace=True)

data['8:00 AM'] = pd.to_numeric(data['8:00 AM'], errors='coerce', downcast='integer')
data['8:00 AM'].replace(1.5,data['8:00 AM'].mean(), inplace=True)

data['9:00 AM'] = pd.to_numeric(data['9:00 AM'], errors='coerce', downcast='integer')
data['9:00 AM'].replace(1.5,data['9:00 AM'].mean(), inplace=True)

data['10:00 AM'] = pd.to_numeric(data['10:00 AM'], errors='coerce', downcast='integer')
data['10:00 AM'].replace(1.5,data['10:00 AM'].mean(), inplace=True)

data['11:00 AM'] = pd.to_numeric(data['11:00 AM'], errors='coerce', downcast='integer')
data['11:00 AM'].replace(1.5,data['11:00 AM'].mean(), inplace=True)

data['12:00 PM'] = pd.to_numeric(data['12:00 PM'], errors='coerce', downcast='integer')
data['12:00 PM'].replace(1.5,data['12:00 PM'].mean(), inplace=True)

data['1:00 PM'] = pd.to_numeric(data['1:00 PM'], errors='coerce', downcast='integer')
data['1:00 PM'].replace(1.5,data['1:00 PM'].mean(), inplace=True)

data['2:00 PM'] = pd.to_numeric(data['2:00 PM'], errors='coerce', downcast='integer')
data['2:00 PM'].replace(1.5,data['2:00 PM'].mean(), inplace=True)

data['3:00 PM'] = pd.to_numeric(data['3:00 PM'], errors='coerce', downcast='integer')
data['3:00 PM'].replace(1.5,data['3:00 PM'].mean(), inplace=True)

data['4:00 PM'] = pd.to_numeric(data['4:00 PM'], errors='coerce', downcast='integer')
data['4:00 PM'].replace(1.5,data['4:00 PM'].mean(), inplace=True)

data['5:00 PM'] = pd.to_numeric(data['5:00 PM'], errors='coerce', downcast='integer')
data['5:00 PM'].replace(1.5,data['5:00 PM'].mean(), inplace=True)

data['6:00 PM'] = pd.to_numeric(data['6:00 PM'], errors='coerce', downcast='integer')
data['6:00 PM'].replace(1.5,data['6:00 PM'].mean(), inplace=True)

data['7:00 PM'] = pd.to_numeric(data['7:00 PM'], errors='coerce', downcast='integer')
data['7:00 PM'].replace(1.5,data['7:00 PM'].mean(), inplace=True)

data['8:00 PM'] = pd.to_numeric(data['8:00 PM'], errors='coerce', downcast='integer')
data['8:00 PM'].replace(1.5,data['8:00 PM'].mean(), inplace=True)

data['9:00 PM'] = pd.to_numeric(data['9:00 PM'], errors='coerce', downcast='integer')
data['9:00 PM'].replace(1.5,data['9:00 PM'].mean(), inplace=True)

data['10:00 PM'] = pd.to_numeric(data['10:00 PM'], errors='coerce', downcast='integer')
data['10:00 PM'].replace(1.5,data['10:00 PM'].mean(), inplace=True)

data['11:00 PM'] = pd.to_numeric(data['11:00 PM'], errors='coerce', downcast='integer')
data['11:00 PM'].replace(1.5,data['11:00 PM'].mean(), inplace=True)


data.fillna(0)
# Out:
#                      Facility                                   Location  \
# 0    Marino Recreation Center                      Marino Center - Track
# 1    Marino Recreation Center                   Marino Center - Studio A
# 2    Marino Recreation Center                   Marino Center - Studio B
# 3    Marino Recreation Center                  Marino Center - Gymnasium
# 4    Marino Recreation Center  Marino Center - 3rd Floor Select & Cardio
# ..                        ...                                        ...
# 505  Marino Recreation Center                   Marino Center - Studio B
# 506  Marino Recreation Center                  Marino Center - Gymnasium
# 507  Marino Recreation Center  Marino Center - 3rd Floor Select & Cardio
# 508  Marino Recreation Center      Marino Center - 3rd Floor Weight Room
# 509  Marino Recreation Center                  Marino Center - 2nd Floor
#
#              Date   5:00 AM  6:00 AM  7:00 AM  8:00 AM    9:00 AM   10:00 AM  \
# 0     1/2/23 0:00  2.786275      1.0      1.0      0.0  15.287819  16.849705
# 1     1/2/23 0:00  2.786275      0.0      0.0      0.0  15.287819  16.849705
# 2     1/2/23 0:00  2.786275      0.0      0.0      0.0  15.287819  16.849705
# 3     1/2/23 0:00  2.786275      1.0      1.0      0.0  15.287819  16.849705
# 4     1/2/23 0:00  2.786275      1.0      3.0      4.0  15.287819  16.849705
# ..            ...       ...      ...      ...      ...        ...        ...
# 505  3/15/23 0:00  0.000000      0.0      2.0      3.0   2.000000   5.000000
# 506  3/15/23 0:00  1.000000     11.0      9.0      2.0   6.000000   3.000000
# 507  3/15/23 0:00  2.786275     12.0     25.0     25.0  27.000000  32.000000
# 508  3/15/23 0:00  2.786275     24.0     25.0     30.0  39.000000  44.000000
# 509  3/15/23 0:00  1.000000     13.0     25.0     36.0  46.000000  33.000000
#
#      11:00 AM  ...  4:00 PM  5:00 PM  6:00 PM  7:00 PM  8:00 PM    9:00 PM  \
# 0         4.0  ...      4.0      5.0      6.0      3.0      1.0  23.350394
# 1         2.0  ...      3.0      2.0      1.0      3.0      1.0  23.350394
# 2         4.0  ...      2.0      3.0      2.0      2.0      1.0  23.350394
# 3         8.0  ...     17.0     21.0     26.0     25.0     24.0  23.350394
# 4        23.0  ...     23.0     24.0     26.0     32.0     22.0  23.350394
# ..        ...  ...      ...      ...      ...      ...      ...        ...
# 505       2.0  ...      9.0      9.0     10.0     10.0     18.0  22.000000
# 506       8.0  ...     51.0     51.0     52.0     68.0     65.0  64.000000
# 507      50.0  ...     43.0     40.0     43.0     59.0     64.0  58.000000
# 508      46.0  ...     61.0     65.0     65.0     53.0     54.0  46.000000
# 509      42.0  ...     45.0     45.0     46.0     69.0     63.0  60.000000
#
#      10:00 PM  11:00 PM  Total Count  Status
# 0    20.54626  8.609252           32  Active
# 1    20.54626  8.609252           13  Active
# 2    20.54626  8.609252           15  Active
# 3    20.54626  8.609252          132  Active
# 4    20.54626  8.609252          203  Active
# ..        ...       ...          ...     ...
# 505  19.00000  8.609252          131  Active
# 506  60.00000  8.609252          537  Active
# 507  56.00000  8.609252          753  Active
# 508  44.00000  8.609252          805  Active
# 509  57.00000  8.609252          761  Active
#
# [510 rows x 24 columns]

# %%
melted_df = pd.melt(data, id_vars=['Date','Facility','Location'], var_name='Hour', value_name='Count')
melted_df.to_csv('Hour_long.csv', index=False)

# %%
hour_data=data.iloc[:,3:22]
mean_dict={}
for col in hour_data:
    mean=data[col].mean()
    mean_dict[col]=mean
df = pd.DataFrame.from_dict(mean_dict, orient='index', columns=['values'])

# %%
plt.figure(figsize=(18, 6))
plt.plot(df['values'])
plt.xlabel("Hour")
plt.ylabel("mean")
# Out:
# Text(0, 0.5, 'mean')

# %%
df=data.iloc[:,2:23]
df = df.groupby('Date').sum().reset_index()
df.set_index(['Date'], inplace=True)
#df['Total_Crowd'] = df.sum(axis=1)
#df = df['Total_Crowd'].round(0).astype(int)
df= pd.DataFrame(df)

#plt.plot(df.index,df['Total_Crowd'])
df
# Out:
#                 5:00 AM    6:00 AM     7:00 AM     8:00 AM     9:00 AM  \
# Date
# 1/10/23 0:00  39.000000  84.000000  101.000000  149.000000  157.000000
# 1/11/23 0:00  12.358824  85.000000  115.000000  151.000000  153.000000
# 1/12/23 0:00  30.000000  68.000000   90.000000  132.000000  146.000000
# 1/13/23 0:00  28.000000  74.000000   90.000000  105.000000  111.000000
# 1/14/23 0:00  19.503922  53.543137   68.033399   63.000000  119.000000
# ...                 ...        ...         ...         ...         ...
# 3/5/23 0:00   19.503922  53.543137   68.033399   26.000000   47.000000
# 3/6/23 0:00   22.000000  35.000000   47.000000   50.000000   40.000000
# 3/7/23 0:00   14.000000  43.000000   53.000000   58.000000   66.000000
# 3/8/23 0:00    0.000000  47.000000   48.000000   46.570727   72.287819
# 3/9/23 0:00    5.000000  21.000000   34.000000   43.000000   59.000000
#
#                 10:00 AM    11:00 AM    12:00 PM  1:00 PM  2:00 PM  3:00 PM  \
# Date
# 1/10/23 0:00  186.000000  175.000000  200.674556    149.0    162.0    203.0
# 1/11/23 0:00  149.000000  200.000000  207.000000    161.0    158.0    193.0
# 1/12/23 0:00  161.000000  150.000000  176.000000    114.0    206.0    251.0
# 1/13/23 0:00  124.000000  143.000000  184.000000    154.0    163.0    172.0
# 1/14/23 0:00  136.000000  154.000000  135.000000    151.0    159.0    146.0
# ...                  ...         ...         ...      ...      ...      ...
# 3/5/23 0:00    64.000000   84.000000  114.000000    134.0    146.0    135.0
# 3/6/23 0:00    46.000000   59.000000   77.000000     80.0    102.0    112.0
# 3/7/23 0:00    83.000000  133.555118   84.000000     79.0     89.0    109.0
# 3/8/23 0:00    82.849705   67.000000   84.000000     81.0     77.0     85.0
# 3/9/23 0:00    68.000000   98.000000   88.000000     85.0     78.0     90.0
#
#                  4:00 PM     5:00 PM     6:00 PM     7:00 PM     8:00 PM  \
# Date
# 1/10/23 0:00  242.000000  236.000000  205.000000  285.000000  238.000000
# 1/11/23 0:00  282.000000  299.000000  304.000000  270.000000  202.000000
# 1/12/23 0:00  233.000000  250.000000  289.996063  261.000000  250.000000
# 1/13/23 0:00  242.000000  225.000000  232.000000  218.000000  211.000000
# 1/14/23 0:00  228.073819  196.117126  222.000000  186.720472  123.000000
# ...                  ...         ...         ...         ...         ...
# 3/5/23 0:00   162.000000  170.000000  217.000000  213.010827  188.464567
# 3/6/23 0:00   130.000000  170.000000  214.000000  230.000000  228.000000
# 3/7/23 0:00   122.000000  165.000000  220.000000  296.430118  265.000000
# 3/8/23 0:00    95.000000  133.000000  147.000000  187.000000  190.000000
# 3/9/23 0:00   118.000000  137.000000  174.000000  193.000000  192.000000
#
#                  9:00 PM    10:00 PM   11:00 PM  Total Count
# Date
# 1/10/23 0:00  235.000000  146.000000  60.264764         3089
# 1/11/23 0:00  233.000000  239.000000  60.264764         3389
# 1/12/23 0:00  230.000000  194.000000  70.827756         3136
# 1/13/23 0:00  167.000000  141.000000  67.827756         2811
# 1/14/23 0:00  107.000000  108.546260  74.000000         1877
# ...                  ...         ...        ...          ...
# 3/5/23 0:00   163.452756  143.823819  60.264764         1425
# 3/6/23 0:00   170.000000  102.731299  43.046260         1801
# 3/7/23 0:00   140.102362  123.277559  51.655512         1756
# 3/8/23 0:00   204.401575  143.823819  60.264764         1499
# 3/9/23 0:00   199.000000  196.000000  60.264764         1863
#
# [73 rows x 20 columns]

# %%
train_data=df['7:00 PM']
train_data=train_data.values
train_data = train_data.astype('float32')
train_data
# Out:
# array([285.     , 270.     , 261.     , 218.     , 186.72047, 213.     ,
#        231.     , 280.     , 304.     , 246.     , 106.     , 191.29036,
#        172.     , 186.     , 278.     , 209.     , 270.29034, 254.     ,
#        274.     , 188.     , 154.     , 126.     , 300.4301 , 239.     ,
#        147.     , 146.29036, 152.     , 154.     , 150.     , 337.     ,
#        270.     , 221.     , 147.     ,  90.     , 281.     , 252.     ,
#        284.     , 278.     , 249.     , 130.     , 107.     , 230.     ,
#        189.     , 314.     , 261.     , 273.     , 225.     , 174.     ,
#        217.     , 286.     , 204.     , 138.43011, 119.     , 144.     ,
#        253.     , 253.     , 306.     , 268.     , 256.     , 222.     ,
#        215.72047, 199.     , 303.     , 277.     , 286.     , 293.     ,
#        231.     , 145.     , 213.01083, 230.     , 296.4301 , 187.     ,
#        193.     ], dtype=float32)

# %%
#Use data until 14 days before as training
x = len(train_data)-10

train=train_data[:x].reshape(-1,1)
test = train_data[x:].reshape(-1,1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
# define generator
n_input = 5
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
X,y = generator[0]
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.78947365 0.728745   0.6923077  0.51821864 0.39158088]
# Predict this y:
#  [[0.4979757]]

# %%
X.shape
# Out:
# (1, 5, 1)

# %%
num_features=1
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(32))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               40800
#
#  dense (Dense)               (None, 32)                3232
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 44,065
# Trainable params: 44,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(generator,epochs=50)
# Out:
# Epoch 1/50
# 58/58 [==============================] - 1s 2ms/step - loss: 0.1020
# Epoch 2/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0751
# Epoch 3/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0688
# Epoch 4/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0686
# Epoch 5/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0679
# Epoch 6/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0639
# Epoch 7/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0752
# Epoch 8/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0623
# Epoch 9/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0590
# Epoch 10/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0595
# Epoch 11/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0595
# Epoch 12/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0564
# Epoch 13/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0540
# Epoch 14/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0542
# Epoch 15/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0585
# Epoch 16/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0577
# Epoch 17/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0555
# Epoch 18/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0522
# Epoch 19/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0516
# Epoch 20/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0524
# Epoch 21/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0517
# Epoch 22/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0508
# Epoch 23/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0549
# Epoch 24/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0521
# Epoch 25/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0514
# Epoch 26/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0518
# Epoch 27/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0545
# Epoch 28/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0506
# Epoch 29/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0567
# Epoch 30/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0530
# Epoch 31/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0493
# Epoch 32/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0518
# Epoch 33/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0508
# Epoch 34/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0503
# Epoch 35/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0506
# Epoch 36/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0498
# Epoch 37/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0516
# Epoch 38/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0523
# Epoch 39/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0553
# Epoch 40/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0490
# Epoch 41/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0473
# Epoch 42/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0486
# Epoch 43/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0507
# Epoch 44/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0493
# Epoch 45/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0446
# Epoch 46/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0509
# Epoch 47/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0490
# Epoch 48/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0488
# Epoch 49/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0455
# Epoch 50/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0490

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
model.save('LSTM_model.h5')

# %%
last_train_batch = scaled_train[-5:]
last_train_batch = last_train_batch.reshape((1, n_input, n_features))

# %%
model.predict(last_train_batch)
# Out:
# 1/1 [==============================] - 0s 121ms/step
# array([[0.6060693]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0.7570851], dtype=float32)

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)+5):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step

# %%
test_predictions
# Out:
# [array([0.5781294], dtype=float32),
#  array([0.40104038], dtype=float32),
#  array([0.31051657], dtype=float32),
#  array([0.38519222], dtype=float32),
#  array([0.49449667], dtype=float32),
#  array([0.59564865], dtype=float32),
#  array([0.63012445], dtype=float32),
#  array([0.5701141], dtype=float32),
#  array([0.47255263], dtype=float32),
#  array([0.42950302], dtype=float32),
#  array([0.47683513], dtype=float32),
#  array([0.53142613], dtype=float32),
#  array([0.5712934], dtype=float32),
#  array([0.5697505], dtype=float32),
#  array([0.5296046], dtype=float32)]

# %%
true_predictions = scaler.inverse_transform(test_predictions)
true_predictions
# Out:
# array([[232.79796408],
#        [189.05697341],
#        [166.6975931 ],
#        [185.14247804],
#        [212.14067847],
#        [237.12521517],
#        [245.64073839],
#        [230.81817649],
#        [206.72049923],
#        [196.08724739],
#        [207.77827778],
#        [221.26225446],
#        [231.10947284],
#        [230.72837017],
#        [220.81233954]])

# %%
import tkinter as tk
import pandas as pd

class App:
    def __init__(self, master):
        self.master = master
        master.title("Choose Columns")

        # Load the dataset
        self.df = pd.read_csv('/Users/harisha/Documents/Northeastern/CS6140/ML project/Modified.csv')
        self.column_names = self.df.columns

        # Create a label to display column names
        self.label = tk.Label(master, text="Columns in the dataset:")
        self.label.pack()

        # Create a listbox to select columns
        self.listbox = tk.Listbox(master, selectmode=tk.MULTIPLE)
        for name in self.column_names:
            self.listbox.insert(tk.END, name)
        self.listbox.pack()

        # Create a button to filter the dataset
        self.filter_button = tk.Button(master, text="Predict", command=self.filter_dataset)
        self.filter_button.pack()

        # Create a text area to display filtered dataset
        self.text_area = tk.Text(master)
        self.text_area.pack()

    def filter_dataset(self):
        # Get the selected column names
        selected_indices = self.listbox.curselection()
        selected_columns = [self.column_names[i] for i in selected_indices]

        # Filter the dataset to only include selected columns
        filtered_df = self.df[selected_columns]
        
        train_data=filtered_df
        train_data=train_data.values
        train_data = train_data.astype('float32')
        
        #Use data until 14 days before as training
        x = len(train_data)-10
        train=train_data[:x].reshape(-1,1)
        test = train_data[x:].reshape(-1,1)
        
        from sklearn.preprocessing import MinMaxScaler
        scaler = MinMaxScaler()
        scaler.fit(train)
        scaled_train = scaler.transform(train)
        scaled_test = scaler.transform(test)
        
        from keras.preprocessing.sequence import TimeseriesGenerator
        # define generator
        n_input = 5
        n_features = 1
        generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)
        
        num_features=1
        model = Sequential()
        model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
        model.add(Dense(32))
        model.add(Dense(1))
        model.compile(optimizer='adam', loss='mean_squared_error')
        
        model.fit(generator,epochs=50)
        test_predictions = []

        first_eval_batch = scaled_train[-n_input:]
        current_batch = first_eval_batch.reshape((1, n_input, n_features))

        for i in range(len(test)+5):
            current_pred = model.predict(current_batch)[0]
            test_predictions.append(current_pred) 
            current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
        
        true_predictions = scaler.inverse_transform(test_predictions)
        true_predictions=np.array(true_predictions)
        true_predictions = np.array2string(true_predictions)
        
        
        
        

        # Display the filtered dataset in the text area
        self.text_area.delete('1.0', tk.END)
        self.text_area.insert(tk.END, true_predictions)

root = tk.Tk()
app = App(root)
root.mainloop()
# Out:
# Epoch 1/50
# 58/58 [==============================] - 1s 2ms/step - loss: 0.0862
# Epoch 2/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0643
# Epoch 3/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0602
# Epoch 4/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0575
# Epoch 5/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0572
# Epoch 6/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0563
# Epoch 7/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0586
# Epoch 8/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0553
# Epoch 9/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0564
# Epoch 10/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0541
# Epoch 11/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0541
# Epoch 12/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0565
# Epoch 13/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0521
# Epoch 14/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0518
# Epoch 15/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0510
# Epoch 16/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0546
# Epoch 17/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0499
# Epoch 18/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0553
# Epoch 19/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0484
# Epoch 20/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0466
# Epoch 21/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0522
# Epoch 22/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0477
# Epoch 23/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0449
# Epoch 24/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0512
# Epoch 25/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0445
# Epoch 26/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0481
# Epoch 27/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0444
# Epoch 28/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0427
# Epoch 29/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0444
# Epoch 30/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0440
# Epoch 31/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0390
# Epoch 32/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0409
# Epoch 33/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0412
# Epoch 34/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0487
# Epoch 35/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0397
# Epoch 36/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0417
# Epoch 37/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0408
# Epoch 38/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0418
# Epoch 39/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 40/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0391
# Epoch 41/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0351
# Epoch 42/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0387
# Epoch 43/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0372
# Epoch 44/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0397
# Epoch 45/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0361
# Epoch 46/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0357
# Epoch 47/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0380
# Epoch 48/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0360
# Epoch 49/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0335
# Epoch 50/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0339
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Epoch 1/50
# 58/58 [==============================] - 1s 2ms/step - loss: 0.1053
# Epoch 2/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0600
# Epoch 3/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0562
# Epoch 4/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0591
# Epoch 5/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0596
# Epoch 6/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0583
# Epoch 7/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0539
# Epoch 8/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0581
# Epoch 9/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0554
# Epoch 10/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0573
# Epoch 11/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0558
# Epoch 12/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0561
# Epoch 13/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0557
# Epoch 14/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0587
# Epoch 15/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0572
# Epoch 16/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0559
# Epoch 17/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0543
# Epoch 18/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0547
# Epoch 19/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0555
# Epoch 20/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0536
# Epoch 21/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0535
# Epoch 22/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0547
# Epoch 23/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0550
# Epoch 24/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0545
# Epoch 25/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0532
# Epoch 26/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0586
# Epoch 27/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0549
# Epoch 28/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0534
# Epoch 29/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0562
# Epoch 30/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0528
# Epoch 31/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0540
# Epoch 32/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0540
# Epoch 33/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0522
# Epoch 34/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0526
# Epoch 35/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0523
# Epoch 36/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0533
# Epoch 37/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0523
# Epoch 38/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0499
# Epoch 39/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0522
# Epoch 40/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0516
# Epoch 41/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0516
# Epoch 42/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0488
# Epoch 43/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0491
# Epoch 44/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0524
# Epoch 45/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0455
# Epoch 46/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0507
# Epoch 47/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0482
# Epoch 48/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0492
# Epoch 49/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0497
# Epoch 50/50
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0467
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
